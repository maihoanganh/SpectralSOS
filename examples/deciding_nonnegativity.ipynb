# %%
using DynamicPolynomials,SparseArrays

println("***Problem setting***")

n=50
d=2

println("Number of variable: n=",n)
println("====================")

@polyvar x[1:n]# variables

# random quadratic objective function f
v=reverse(monomials(x,2*d))
c=Vector(2*sprand(Float64,length(v),0.1).-1)
f=c'*v


# unit sphere constraint
R=1.0
h=[R-sum(x.^2)] #type of coefficients of each polynomial must be float

l_h=length(h)

println("Number of equality constraints: l_h=",l_h)
println("====================")

k=Int64(d)

println("Relaxed order: k=",k)
    

    
#end
# Out:
# ***Problem setting***
# Number of variable: n=50
# ====================
# Number of equality constraints: l_h=1
# ====================
# Relaxed order: k=2

# %%
# using SparseArrays

# include("../src/SpectralPOP.jl")
# using .SpectralPOP



# include("../examples/densePOPsphere_deg4_var5_nineq0_neq1.jl")

# x,f,g,h=SpectralPOP.get_POP(n,m,l,lmon_g,supp_g,coe_g,lmon_h,supp_h,coe_h,lmon_f,supp_f,coe_f);


# k=2

# %%
# include("../src/SpectralPOP.jl")
# using .SpectralPOP

# g=Vector{Polynomial{true,Float64}}([])

# opt_val = SpectralPOP.SumofSquares_POP(x,f,g,h,k)

# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP


opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R;method="LMBM",EigAlg="Mix",tol=1e-5,scale=true)
# Out:
# **Constant trace property (CTP):
# **Convert moment relaxation to standard SDP:
# WARNING: replacing module SpectralPOP.
#   Size of psd matrix: sk=1326
#   Number of equality trace constraints: m=564877
# 200.475687 seconds (50.76 M allocations: 15.631 GiB, 1.56% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       564877
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        125
# N. func. eval.:  207
# Final value:     0.193259
# Execution time:  125.721436
#  48.334839 seconds (1.34 M allocations: 8.337 GiB, 0.25% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-105.53204074902204
# ====================================
# Dimension of the null space of Gram matrix = 2
# ------------------------------------
# atom 1 = [0.14191005373726479, 0.14146361244630856, 0.14122178415310127, 0.14117463914070838, 0.14113824596289407, 0.14162887223208745, 0.14133786941970092, 0.1414820076631808, 0.14137201352350107, 0.14101775253379442, 0.14055901812173854, 0.14154705538286405, 0.14191368944583643, 0.14150166332260092, 0.14165823918817616, 0.14106886178766467, 0.14153418145787142, 0.14152548355026376, 0.141717829369702, 0.14172856059986252, 0.14132306546839882, 0.14166259269205553, 0.14185529408705658, 0.14130247992563846, 0.14148886171789546, 0.14059876037838953, 0.1422633533424981, 0.1415247500382087, 0.14124201599517602, 0.14142412392085135, 0.1415615807777243, 0.141517295422538, 0.1413076378207891, 0.14095573079977125, 0.14210276252765494, 0.14119119702133806, 0.1415265674969712, 0.14116582732475874, 0.14076362968666886, 0.14116169954339905, 0.14130387340235434, 0.14155714093065774, 0.14094992718692304, 0.1412434269153202, 0.1415829317636258, 0.14123729971192897, 0.14168387858017467, 0.1413251204337111, 0.1417970015391509, 0.1414535170281162]
#   check gap of lower bound  = 0.028237530435333724
#   check equality constraint 1 = 0.00013379440949046195
# ####################################
# Optimal solution: opt_sol = [0.14191005373726479, 0.14146361244630856, 0.14122178415310127, 0.14117463914070838, 0.14113824596289407, 0.14162887223208745, 0.14133786941970092, 0.1414820076631808, 0.14137201352350107, 0.14101775253379442, 0.14055901812173854, 0.14154705538286405, 0.14191368944583643, 0.14150166332260092, 0.14165823918817616, 0.14106886178766467, 0.14153418145787142, 0.14152548355026376, 0.141717829369702, 0.14172856059986252, 0.14132306546839882, 0.14166259269205553, 0.14185529408705658, 0.14130247992563846, 0.14148886171789546, 0.14059876037838953, 0.1422633533424981, 0.1415247500382087, 0.14124201599517602, 0