# %%
using DynamicPolynomials

println("***Problem setting***")

n=30
#N=[5;10;15;20;25;30]

#for n in N

println("Number of variable: n=",n)
println("====================")

@polyvar x[1:n]# variables

# random quadratic objective function f
v=reverse(monomials(x,0:4))
c=2*rand(Float64,length(v)).-1
f=c'*v


# unit sphere constraint
R=1.0
h=[R-sum(x.^2)] #type of coefficients of each polynomial must be float

l_h=length(h)

println("Number of equality constraints: l_h=",l_h)
println("====================")

k=Int64(2)

println("Relaxed order: k=",k)
    

    
#end
# Out:
# ***Problem setting***
# Number of variable: n=30
# ====================
# Number of equality constraints: l_h=1
# ====================
# Relaxed order: k=2

# %%
# using SparseArrays

# include("../src/SpectralPOP.jl")
# using .SpectralPOP



# include("../examples/densePOPsphere_deg4_var5_nineq0_neq1.jl")

# x,f,g,h=SpectralPOP.get_POP(n,m,l,lmon_g,supp_g,coe_g,lmon_h,supp_h,coe_h,lmon_f,supp_f,coe_f);


# k=2

# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP

g=Vector{Polynomial{true,Float64}}([])

opt_val = SpectralPOP.SumofSquares_POP(x,f,g,h,k)

# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP


opt_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R;method="LMBM",EigAlg="Mix",tol=1e-5,scale=true)
# Out:
# **Constant trace property (CTP):
# **Convert moment relaxation to standard SDP:
# WARNING: replacing module SpectralPOP.
#   Size of psd matrix: sk=496
#   Number of equality trace constraints: m=77377
#   9.299372 seconds (6.17 M allocations: 1.403 GiB, 42.73% gc time)
# **LMBM solver:
# ---------------
# | Parameters: |
# ---------------
# n:       77377
# maxtime: 300000.000000
# na:      2
# mcu:     5
# mc:      7
# rpar:
# ipar:
# -----------
# | Output: |
# -----------
# Termination:     2
# N. iter.:        1512
# N. func. eval.:  6104
# Final value:     0.046421
# Execution time:  2859.152344
# 708.252187 seconds (40.58 M allocations: 46.828 GiB, 0.25% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-6.203333141041099
# ====================================
# Dimension of the null space of Gram matrix = 9
# ------------------------------------
# atom 1 = [0.007308106076889317, -0.043494010161405826, -0.16424800307031298, 0.07756261686121656, 0.06852264167473836, 0.1595143542529718, -0.01493683851107071, -0.036957579406816925, -0.019233584730806892, 0.02562459392286466, -0.24310652061030896, -0.581117225034173, -1.0627544299065919, -0.30180384138778765, -0.6266994902997429, -0.040346587694278756, 0.12463131700980103, -0.0018756800567604655, 0.4594431892412635, -0.5106011243218106, -0.14744121761818602, 0.20065218648937513, -0.7213037438349392, -0.266755442420476, -0.22039258769648756, -0.2726204878819173, -0.21163821163359464, -0.4252487673222635, 0.18059400620838648, 0.08470556489540144]
#   check gap of lower bound  = 4.370255208737375
#   check equality constraint 1 = 2.608491955110299
# ------------------------------------
t_val,opt_sol = SpectralPOP.CTP_POP(x,f,h,k,R;method="SketchyCGAL",EigAlg="Normal",tol=1e-3,scale=true)
# Out:
# **Constant trace property (CTP):
# **Convert moment relaxation to standard SDP:
# WARNING: replacing module SpectralPOP.
#   Size of psd matrix: sk=496
#   Number of equality trace constraints: m=77377
#   3.112978 seconds (6.17 M allocations: 1.401 GiB, 5.85% gc time)
# **SketchyCGAL solver:
# - SketchyCGAL SDP Solver - Beta.V.0.0
# --------------------------
#  iter=1
#  stopObj=0.13486963954417644
#  stopFeas=0.15872113987467232
#  primalObj=-0.06965556333193137
# --------------------------
#  iter=2
#  stopObj=0.6436268841641724
#  stopFeas=0.5919846523474799
#  primalObj=-0.07062563169492861
# --------------------------
#  iter=4
#  stopObj=0.34565984909752573
#  stopFeas=0.3543709341916356
#  primalObj=-0.05155557451245485
# --------------------------
#  iter=8
#  stopObj=0.2573312254126512
#  stopFeas=0.21933967763789622
#  primalObj=-0.034703149746046616
# --------------------------
#  iter=16
#  stopObj=0.21193337931206863
#  stopFeas=0.13416669212256704
#  primalObj=-0.036321654302220285
# --------------------------
#  iter=32
#  stopObj=0.12863908785888403
#  stopFeas=0.09061944870321643
#  primalObj=-0.04155564892100244
# --------------------------
#  iter=64
#  stopObj=0.10552284124068098
#  stopFeas=0.051223344175978784
#  primalObj=-0.036515389406854774
# --------------------------
#  iter=128
#  stopObj=0.08503549404578806
#  stopFeas=0.02742961890056986
#  primalObj=-0.028988653052435
# --------------------------
#  iter=256
#  stopObj=0.06342140603453009
#  stopFeas=0.01606839860996603
#  primalObj=-0.025032484938983107
# --------------------------
#  iter=512
#  stopObj=0.03989590759040271
#  stopFeas=0.009658552803938705
#  primalObj=-0.02636701972697502
# --------------------------
#  iter=1024
#  stopObj=0.023302584860273798
#  stopFeas=0.004337897345196249
#  primalObj=-0.03040896408945569
# --------------------------
#  iter=2048
#  stopObj=0.009599377749105853
#  stopFeas=0.0014802352847314865
#  primalObj=-0.03678998538280473
# --------------------------
#  iter=4096
#  stopObj=0.003947850539301884
#  stopFeas=0.00041893086761571053
#  primalObj=-0.042144259140732276
# * status = stopping criteria met
# 2122.113673 seconds (14.81 M allocations: 1.301 TiB, 1.57% gc time)
# ------------------------------------
# **Numerical result:
# ====================================
# opt_val=-5.748570364758839
# ====================================
# Rank of moment matrix = 496
#   0.010542 seconds (1.06 k allocations: 11.387 MiB)
# 2125.238153 seconds (20.98 M allocations: 1.303 TiB, 1.58% gc time)
# (-5.748570364758839, Array{Float64,1}[])

# %%
include("../src/SpectralPOP.jl")
using .SpectralPOP

g=Vector{Polynomial{true,Float64}}([])

SpectralPOP.save_data(x,f,g,h,R)
